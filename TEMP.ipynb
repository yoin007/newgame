# %%
for i in range(9):
    for j in range(i):
        print("*",end='')
    print()
# Out:
# *
# **
# ***
# ****
# *****
# ******
# *******
# ********

# %%
import requests
import json

# %%
url = u"https://api.wanmen.org/4.0/content/majors?app=web"
r = requests.get(url)
bytes.decode(r.content)  
print(r.content)
# Out:
# b'[{"_id":"5a4302d90b61756f4d2c4495","deletedAt":null,"deleted":false,"createdAt":"2017-12-27T02:18:01.801Z","updatedAt":"2017-12-28T03:29:41.160Z","name":"\xe7\x95\x99\xe5\xad\xa6\xe7\xbb\x8f\xe9\xaa\x8c","logo":"https://imgs.wanmen.org/0acb64f81048233145ba8e80f6dc3de8.png","hide":false,"genre":"586d234a5f071276741397fe","id":"5a4302d90b61756f4d2c4495"},{"_id":"5a43044f0b61756f4d2c44a1","deletedAt":null,"deleted":false,"createdAt":"2017-12-27T02:24:15.625Z","updatedAt":"2017-12-28T01:44:53.746Z","name":"\xe8\x89\xba\xe6\x9c\xaf","logo":"https://imgs.wanmen.org/823023eed32361b1291132b7cadc77ea.png","hide":false,"genre":"586d234a5f071276741397fc","id":"5a43044f0b61756f4d2c44a1"},{"_id":"5a43045f0b61756f4d2c44a3","deletedAt":null,"deleted":false,"createdAt":"2017-12-27T02:24:31.536Z","updatedAt":"2017-12-28T01:45:15.874Z","name":"\xe5\x8e\x86\xe5\x8f\xb2","logo":"https://imgs.wanmen.org/4ec70810ce495ab6734a172ef792a66f.png","hide":false,"genre":"586d234a5f071276741397fc","id":"5a43045f
# ...

# %%
for i in range(1,10):
    for j in range(1,i+1):
        print("%d*%d=%2d\t"%(j,i,i*j),end='')
    print()
# Out:
# 1*1= 1
# 1*2= 2	2*2= 4
# 1*3= 3	2*3= 6	3*3= 9
# 1*4= 4	2*4= 8	3*4=12	4*4=16
# 1*5= 5	2*5=10	3*5=15	4*5=20	5*5=25
# 1*6= 6	2*6=12	3*6=18	4*6=24	5*6=30	6*6=36
# 1*7= 7	2*7=14	3*7=21	4*7=28	5*7=35	6*7=42	7*7=49
# 1*8= 8	2*8=16	3*8=24	4*8=32	5*8=40	6*8=48	7*8=56	8*8=64
# 1*9= 9	2*9=18	3*9=27	4*9=36	5*9=45	6*9=54	7*9=63	8*9=72	9*9=81
